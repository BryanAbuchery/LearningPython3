# %%
import os

# %%
os.getcwd()
# Out:
# '/home/abuchery/Documents/LearningPython3/portal-teachingdb-master'

# %%
os.chdir("/portal-teachingdb-master")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-d909764dca62> in <module>
# ----> 1 os.chdir("/portal-teachingdb-master")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/portal-teachingdb-master'

# %%
os.getcwd()
# Out:
# '/home/abuchery/Documents/LearningPython3/portal-teachingdb-master'

# %%
import pandas as pd

# %%
surveys_df = pd.read_csv("surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
species_counts = surveys_df.groupby("species_id")["record_id"]

# %%
print(species_counts)

# %%
species_counts.plot(kind="bar")

# %%
plot = species_counts.plot(kind="bar")

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()

# %%
total_count.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='plot_id'>

# %%
weight_count = surveys_df.groupby('weight').count()

# %%
weight_count.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
by_site_sex = surveys_df.groupby(['plot_id', 'sex'])

# %%
site_sex_count = by_site_sex['weight'].sum()

# %%
site_sex_count.plot(kind='bar', stacked=True, title="Stacked Bar Plot of Weight and Sex")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:title={'center':'Stacked Bar Plot of Weight and Sex'}, xlabel='plot_id,sex'>

# %%
by_site_sex = surveys_df.groupby(['plot_id', 'sex'])
site_sex_count = by_site_sex['weight'].sum()
spc = site_sex_count.unstack()
s_plot = spc.plot(kind='bar', stacked=True, title="Total weight by site and sex")
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Plot_id")
# Out:
# Text(0.5, 0, 'Plot_id')

# %%
surveys_df['species_id']
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
#         ...
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
surveys_species = surveys_df['species_id']

# %%
surveys_species
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
#         ...
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
surveys_df[['species_id', 'plot_id']]
# Out:
#       species_id  plot_id
# 0             NL        2
# 1             NL        3
# 2             DM        2
# 3             DM        7
# 4             DM        3
# ...          ...      ...
# 35544         AH       15
# 35545         AH       15
# 35546         RM       10
# 35547         DO        7
# 35548        NaN        5
#
# [35549 rows x 2 columns]

# %%
surveys_df[:5]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df[:-1]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
#
#        weight
# 0         NaN
# ...

# %%
surveys_df[-1:]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35548     NaN

# %%
surveys_df.iloc[0:3, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977

# %%
surveys_df.loc[[0, 10], :]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL   M             32.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 0      NaN
# 10     NaN

# %%
surveys_df.loc[0, ['species_id', 'plot_id', 'weight']]
# Out:
# species_id     NL
# plot_id         2
# weight        NaN
# Name: 0, dtype: object

# %%
surveys_df[0:1]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
#
#    weight
# 0     NaN

# %%
surveys_df[:4]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN

# %%
surveys_df[:-1]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.iloc[0:4, 1:5]
# Out:
#    month  day  year  plot_id
# 0      7   16  1977        2
# 1      7   16  1977        3
# 2      7   16  1977        2
# 3      7   16  1977        7

# %%
surveys_df[surveys_df.year == 2002]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 33320      33321      1   12  2002        1         DM    M             38.0
# 33321      33322      1   12  2002        1         DO    M             37.0
# 33322      33323      1   12  2002        1         PB    M             28.0
# 33323      33324      1   12  2002        1         AB  NaN              NaN
# 33324      33325      1   12  2002        1         DO    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 33320    44.0
# ...

# %%
surveys_df[(surveys_df.year >= 1980) & (surveys_df.year <= 1985)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2270        2271      1   15  1980        8         DO    M             35.0
# 2271        2272      1   15  1980       11         PF    F             16.0
# 2272        2273      1   15  1980       18         DM    F             34.0
# 2273        2274      1   15  1980       11         DM    M             38.0
# 2274        2275      1   15  1980        8         DO    F             33.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 11222      11223     12    8  1985        4         DM    M             36.0
# 11223      11224     12    8  1985       11         DM    M             37.0
# 11224      11225     12    8  1985        7         PE    M             20.0
# 11225      11226     12    8  1985        1         DM    M             38.0
# 11226      11227     12    8  1985       15        NaN  NaN              NaN
#
#        weight
# 2270     53.0
# ...

# %%
surveys_df[(surveys_df.year == 1999) & (surveys_df.weight <= 8)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 29082      29083      1   16  1999       21         RM   M             16.0
# 29196      29197      2   20  1999       18         RM   M             18.0
# 29421      29422      3   15  1999       16         RM   M             15.0
# 29903      29904     10   10  1999        4         PP   M             20.0
# 29905      29906     10   10  1999        4         PP   M             21.0
#
#        weight
# 29082     8.0
# 29196     8.0
# 29421     8.0
# 29903     7.0
# 29905     4.0

# %%
pd.isnull(surveys_df)
# Out:
#        record_id  month    day   year  plot_id  species_id    sex  \
# 0          False  False  False  False    False       False  False
# 1          False  False  False  False    False       False  False
# 2          False  False  False  False    False       False  False
# 3          False  False  False  False    False       False  False
# 4          False  False  False  False    False       False  False
# ...          ...    ...    ...    ...      ...         ...    ...
# 35544      False  False  False  False    False       False   True
# 35545      False  False  False  False    False       False   True
# 35546      False  False  False  False    False       False  False
# 35547      False  False  False  False    False       False  False
# 35548      False  False  False  False    False        True   True
#
#        hindfoot_length  weight
# 0                False    True
# 1                False    True
# 2                False    True
# 3                False    True
# ...

# %%
surveys_df[pd.isnull(surveys_df).any(axis=1)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
empty_weights = surveys_df[pd.isnull(surveys_df['weight'])]['weight']
print(empty_weights)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 35530   NaN
# 35543   NaN
# 35544   NaN
# 35545   NaN
# 35548   NaN
# Name: weight, Length: 3266, dtype: float64

# %%
len(surveys_df[pd.isnull(surveys_df.weight)])
# Out:
# 3266

# %%
len(surveys_df[surveys_df.weight > 0])
# Out:
# 32283

# %%
df1 = surveys_df.copy()

# %%
df1['weight'] = df1['weight'].fillna(0)

# %%
df1['weight'].mean()
# Out:
# 38.751976145601844

# %%
df1['weight'] = surveys_df['weight'].fillna(surveys_df['weight'].mean())

# %%
df1
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#           weight
# 0      42.672428
# ...

# %%
surveys_df = pd.read_csv("surveys.csv")
df_na = surveys_df.dropna()

# %%
df_na.to_csv('surveys_complete.csv', index=False)

# %%
species_df = pd.read_csv("species.csv",
                         keep_default_na=False, na_values=[""])

# %%
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
survey_sub = surveys_df.head(10)

# %%
survey_sub_last10 = surveys_df.tail(10)

# %%
survey_sub_last10 = survey_sub_last10.reset_index(drop=True)

# %%
survey_sub_last10
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# 2      35542     12   31  2002       15         PB    F             26.0
# 3      35543     12   31  2002       15         PB    F             27.0
# 4      35544     12   31  2002       15         US  NaN              NaN
# 5      35545     12   31  2002       15         AH  NaN              NaN
# 6      35546     12   31  2002       15         AH  NaN              NaN
# 7      35547     12   31  2002       10         RM    F             15.0
# 8      35548     12   31  2002        7         DO    M             36.0
# 9      35549     12   31  2002        5        NaN  NaN              NaN
#
#    weight
# 0    23.0
# 1    31.0
# 2    29.0
# 3    34.0
# 4     NaN
# 5     NaN
# 6     NaN
# 7    14.0
# 8    51.0
# 9     NaN

# %%
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)

# %%
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)

# %%
horizontal_stack
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight  record_id  month  day  year  plot_id species_id  sex  \
# 0     NaN      35540     12   31  2002       15         PB    F
# ...

# %%
vertical_stack.to_csv('out.csv', index=False)

# %%
new_output = pd.read_csv('out.csv', keep_default_na=False, na_values=[""])

# %%
new_output
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
file1 = pd.read_csv("surveys2001.csv")
file1
# Out:
#       Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0          31710      31711      1   21  2001        1         PB   F
# 1          31711      31712      1   21  2001        1         DM   M
# 2          31712      31713      1   21  2001        1         PB   M
# 3          31713      31714      1   21  2001        1         DO   M
# 4          31714      31715      1   21  2001        2         OT   M
# ...          ...        ...    ...  ...   ...      ...        ...  ..
# 1429       33303      33304     12   15  2001       24         RM   M
# 1430       33304      33305     12   15  2001        7         PB   M
# 1431       33305      33306     12   15  2001        7         OT   M
# 1432       33306      33307     12   15  2001        7         OT   M
# 1433       33307      33308     12   15  2001        7         PP   M
#
#       hindfoot_length  weight
# 0                26.0    25.0
# 1                37.0    43.0
# 2                29.0    44.0
# ...

# %%
file2 = pd.read_csv("surveys2002.csv")
file2
# Out:
#       Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0          33320      33321      1   12  2002        1         DM   M
# 1          33321      33322      1   12  2002        1         DO   M
# 2          33322      33323      1   12  2002        1         PB   M
# 3          33324      33325      1   12  2002        1         DO   M
# 4          33325      33326      1   12  2002        2         OT   F
# ...          ...        ...    ...  ...   ...      ...        ...  ..
# 2073       35540      35541     12   31  2002       15         PB   F
# 2074       35541      35542     12   31  2002       15         PB   F
# 2075       35542      35543     12   31  2002       15         PB   F
# 2076       35546      35547     12   31  2002       10         RM   F
# 2077       35547      35548     12   31  2002        7         DO   M
#
#       hindfoot_length  weight
# 0                38.0    44.0
# 1                37.0    58.0
# 2                28.0    45.0
# ...

# %%
file_stacked = pd.concat([file1, file2], axis=0)

# %%
file_stacked
# Out:
#       Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0          31710      31711      1   21  2001        1         PB   F
# 1          31711      31712      1   21  2001        1         DM   M
# 2          31712      31713      1   21  2001        1         PB   M
# 3          31713      31714      1   21  2001        1         DO   M
# 4          31714      31715      1   21  2001        2         OT   M
# ...          ...        ...    ...  ...   ...      ...        ...  ..
# 2073       35540      35541     12   31  2002       15         PB   F
# 2074       35541      35542     12   31  2002       15         PB   F
# 2075       35542      35543     12   31  2002       15         PB   F
# 2076       35546      35547     12   31  2002       10         RM   F
# 2077       35547      35548     12   31  2002        7         DO   M
#
#       hindfoot_length  weight
# 0                26.0    25.0
# 1                37.0    43.0
# 2                29.0    44.0
# ...

# %%
file_stacked = file_stacked.reset_index(drop=True)

# %%
file_stacked
# Out:
#       Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0          31710      31711      1   21  2001        1         PB   F
# 1          31711      31712      1   21  2001        1         DM   M
# 2          31712      31713      1   21  2001        1         PB   M
# 3          31713      31714      1   21  2001        1         DO   M
# 4          31714      31715      1   21  2001        2         OT   M
# ...          ...        ...    ...  ...   ...      ...        ...  ..
# 3507       35540      35541     12   31  2002       15         PB   F
# 3508       35541      35542     12   31  2002       15         PB   F
# 3509       35542      35543     12   31  2002       15         PB   F
# 3510       35546      35547     12   31  2002       10         RM   F
# 3511       35547      35548     12   31  2002        7         DO   M
#
#       hindfoot_length  weight
# 0                26.0    25.0
# 1                37.0    43.0
# 2                29.0    44.0
# ...

# %%
file_stacked = file_stacked.dropna()
file_stacked.to_csv('file_stacked.csv', index=False)
file_stacked_df = pd.read_csv("file_stacked.csv")

# %%
by_year_sex = file_stacked_df.groupby(['year', 'sex'])
year_sex_count = by_year_sex['weight'].mean()
newfile = year_sex_count.unstack()
s_plot = newfile.plot(kind='bar', stacked=True, title="Total weight by year and sex")
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Year")
import matplotlib.pyplot as plt
Results = plt.savefig("s_plot.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import numpy as np

# %%
from PIL import Image

# %%
img = np.array(Image.open("s_plot.png"))

# %%
import csv

# %%
def csvWriter(S_plot, nparray):
    example = nparray.tolist()
    with open(S_plot + '.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile, delimiter=',')
        writer.writerows(example)
csvWriter("S_plot", img)

# %%
S_plot_df = pd.read_csv("S_plot.csv", keep_default_na=False, na_values=[""])
S_plot_df
# Out:
#       [255, 255, 255, 0] [255, 255, 255, 0].1 [255, 255, 255, 0].2  \
# 0     [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 1     [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 2     [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 3     [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 4     [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# ...                  ...                  ...                  ...
# 1214  [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 1215  [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 1216  [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 1217  [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# 1218  [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
#
#      [255, 255, 255, 0].3 [255, 255, 255, 0].4 [255, 255, 255, 0].5  \
# 0      [255, 255, 255, 0]   [255, 255, 255, 0]   [255, 255, 255, 0]
# ...

# %%
survey_sub = surveys_df.head(10)
survey_sub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
species_sub = pd.read_csv('speciesSubset.csv', keep_default_na=False, na_values=[""])
species_sub
# Out:
#   species_id       genus   species    taxa
# 0         DM   Dipodomys  merriami  Rodent
# 1         NL     Neotoma  albigula  Rodent
# 2         PE  Peromyscus  eremicus  Rodent

# %%
species_sub.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
survey_sub.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
merged_inner = pd.merge(left=survey_sub, right=species_sub, left_on='species_id', right_on='species_id')
merged_inner.shape
merged_inner
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN   Dipodomys  merriami  Rodent
# ...

# %%
merged_left = pd.merge(left=survey_sub, right=species_sub, how='left', left_on='species_id', right_on='species_id')
merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# ...

# %%
merged_left[ pd.isnull(merged_left.genus) ]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 5          6      7   16  1977        1         PF   M             14.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight genus species taxa
# 5     NaN   NaN     NaN  NaN
# 9     NaN   NaN     NaN  NaN

# %%
surveys_file = pd.read_csv("surveys.csv")
surveys_file
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
species_file = pd.read_csv("species.csv")
species_file
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
merged_inner_file = pd.merge(left=surveys_file, right=species_file, left_on='species_id', right_on='species_id')
merged_inner_file = merged_inner_file
merged_inner_file = merged_inner_file.reset_index(drop=True)
merged_inner_file
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2             22      7   17  1977       15         NL    F             31.0
# 3             38      7   17  1977       17         NL    M             33.0
# 4             72      8   19  1977        2         NL    M             31.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 34781      28988     12   23  1998        6         CT  NaN              NaN
# 34782      35512     12   31  2002       11         US  NaN              NaN
# 34783      35513     12   31  2002       11         US  NaN              NaN
# 34784      35528     12   31  2002       13         US  NaN              NaN
# 34785      35544     12   31  2002       15         US  NaN              NaN
#
# ...

# %%
merged_inner_file.to_csv('merged_inner_file.csv', index=False)
merged_inner_file
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2             22      7   17  1977       15         NL    F             31.0
# 3             38      7   17  1977       17         NL    M             33.0
# 4             72      8   19  1977        2         NL    M             31.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 34781      28988     12   23  1998        6         CT  NaN              NaN
# 34782      35512     12   31  2002       11         US  NaN              NaN
# 34783      35513     12   31  2002       11         US  NaN              NaN
# 34784      35528     12   31  2002       13         US  NaN              NaN
# 34785      35544     12   31  2002       15         US  NaN              NaN
#
# ...

# %%
myfile_df = pd.read_csv("merged_inner_file.csv")
myfile = myfile_df[["plot_id", "taxa"]]
myfile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9443f5c33313> in <module>
# ----> 1 myfile_df = pd.read_csv("merged_inner_file.csv")
#       2 myfile = myfile_df[["plot_id", "taxa"]]
#       3 myfile
#
# NameError: name 'pd' is not defined

# %%
test = myfile.groupby(["plot_id"])
plotting = test.plot(kind="bar")
# Out:
# /home/abuchery/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Error in callback <function flush_figures at 0x7f1881484c10> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ...

# %%
mif_df = pd.read_csv("merged_inner_file.csv")
my_mif = mif_df.groupby(["taxa"])
#my_mif = my_mif["weight"].sum()
#distribution_plot = my_mif.unstack()
distribution_plot = my_mif.plot(kind="bar", stacked=True, title="Taxa Distribution")
#distribution_plot.set_ylabel("Taxa")
#distribution_plot.set_xlabel("Plot_ID")
